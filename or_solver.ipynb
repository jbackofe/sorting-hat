# %% [markdown]
# ## MIPs Adjustable Weight

# %%
import random
from ortools.linear_solver import pywraplp

# %%
# def solve_student_project_assignment(students, projects, project_preferences, student_preferences, project_pref_weight, student_pref_weight):
#     solver = pywraplp.Solver.CreateSolver('SCIP')
#     if not solver:
#         print("Solver not found")
#         return

#     # Decision variables for project assignment
#     x = {}
#     for s in students:
#         for p in projects:
#             if students[s]['major'] in projects[p]['majors']:
#                 x[s, p] = solver.BoolVar(f'x[{s},{p}]')

#     # Decision variables for student pair preferences
#     y = {}
#     for s1 in student_preferences:
#         for s2 in student_preferences[s1]:
#             y[s1, s2] = solver.BoolVar(f'y[{s1},{s2}]')

#     # Hard constraints
#     # Each student must be assigned 1 project
#     for s in students:
#         solver.Add(solver.Sum([x[s, p] for p in projects if (s, p) in x]) == 1)

#     # Do not exceed maximum number of students in a major for each project
#     for p in projects:
#         for m in projects[p]['majors']:
#             solver.Add(solver.Sum([x[s, p] for s in students if students[s]['major'] == m and (s, p) in x]) <= projects[p]['majors'][m])

#     # Student-student pairing preferences constraints
#     for s1 in student_preferences:
#         for s2 in student_preferences[s1]:
#             for p in projects:
#                 if (s1, p) in x and (s2, p) in x:
#                     solver.Add(y[s1, s2] <= x[s1, p])
#                     solver.Add(y[s1, s2] <= x[s2, p])

#     # Soft constraints
#     # Adjusting the project preferences weight based on preference order
#     project_preferences_score = solver.Sum([project_pref_weight * (len(project_preferences[s]) - project_preferences[s].index(p)) * x[s, p]
#                                            for s in project_preferences
#                                            for p in project_preferences[s]
#                                            if (s, p) in x])
    
#     student_preferences_score = solver.Sum([student_pref_weight * y[s1, s2]
#                                             for s1 in student_preferences
#                                             for s2 in student_preferences[s1]])

#     # Objective function
#     solver.Maximize(project_preferences_score + student_preferences_score)

#     # Solve the problem
#     status = solver.Solve()

#     # Output the solution
#     solution = []
#     if status == pywraplp.Solver.OPTIMAL:
#         # print('Solution:')
#         for s in students:
#             for p in projects:
#                 if (s, p) in x and x[s, p].solution_value() > 0.5:
#                     solution.append({'student': s, 'project': p})
#                     # print(f'Student {s} is assigned to project {p}')
#         return solution
#     else:
#         print('The problem does not have an optimal solution.')
#         return None


def solve_student_project_assignment(students, projects, project_preferences, decay_factor=0.5, seat_fill_weight=1):
    solver = pywraplp.Solver.CreateSolver('SCIP')
    if not solver:
        print("Solver not found")
        return

    # Decision variables for project assignment
    x = {}
    for s in students:
        for p in projects:
            if students[s]['major'] in projects[p]['majors']:
                x[s, p] = solver.BoolVar(f'x[{s},{p}]')

    # Hard constraints
    # Each student must be assigned 1 project
    for s in students:
        solver.Add(solver.Sum([x[s, p] for p in projects if (s, p) in x]) == 1)

    # Do not exceed maximum number of students in a major for each project
    for p in projects:
        for m in projects[p]['majors']:
            solver.Add(solver.Sum([x[s, p] for s in students if students[s]['major'] == m and (s, p) in x]) <= projects[p]['majors'][m])

    # Soft constraints
    # Exponential decay for project preferences
    project_preferences_score = solver.Sum(
        [(decay_factor ** project_preferences[s].index(p)) * x[s, p]
         for s in project_preferences
         for p in project_preferences[s]
         if (s, p) in x])

    # Score for filling seats in a project
    seat_filling_score = solver.Sum([x[s, p] for s in students for p in projects if (s, p) in x]) * seat_fill_weight

    # Objective function
    solver.Maximize(project_preferences_score + seat_filling_score)

    # Solve the problem
    status = solver.Solve()

    # Output the solution
    solution = []
    if status == pywraplp.Solver.OPTIMAL:
        for s in students:
            for p in projects:
                if (s, p) in x and x[s, p].solution_value() > 0.5:
                    solution.append({'student': s, 'project': p})
        return solution
    else:
        print('The problem does not have an optimal solution.')
        return None

# %%
# Example Usage
students = {
    'Alice': {'major': 'Computer Science'},
    'Bob': {'major': 'Engineering'},
    'Joe': {'major': 'Engineering'},
    'Ben': {'major': 'Engineering'},
    'Jared': {'major': 'Computer Science'},
    'Bella': {'major': 'Computer Science'},
    # Add other students
}

projects = {
    'Project1': {'majors': {'Computer Science': 2, 'Engineering': 2}},
    'Project2': {'majors': {'Computer Science': 2, 'Engineering': 2}},
    # Add other projects
}

project_preferences = {
    'Alice': ['Project1', 'Project2'],
    'Bob': ['Project2', 'Project1'],
    'Joe': ['Project2', 'Project1'],
    'Ben': ['Project2', 'Project1'],
    'Jared': ['Project1', 'Project2'],
    'Bella': ['Project1', 'Project2'],
    # Add other project preferences
}

student_preferences = {
    'Alice': ['Joe'],
    'Joe': ['Ben'],
    # Add other student preferences
}

solve_student_project_assignment(students, projects, project_preferences)
# Out:
# [{'student': 'Alice', 'project': 'Project1'},
#  {'student': 'Bob', 'project': 'Project2'},
#  {'student': 'Joe', 'project': 'Project1'},
#  {'student': 'Ben', 'project': 'Project2'},
#  {'student': 'Jared', 'project': 'Project1'},
#  {'student': 'Bella', 'project': 'Project2'}]

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import json

# %%
students_df = pd.read_csv('students.csv', index_col=0)
students_df = students_df.set_index('id')
students_df = students_df.rename(columns={'Name': 'name', 'Degree': 'degree', 'Other_desc': 'desc', 'Major': 'major'})
students_df['project_order'] = students_df['project_order'].apply(lambda x: x[1:-1].replace("'", "").replace(" ", "").split(','))
students_df
# Out:
#                       name                          degree  \
# id
# 0         Dechant, Bradley          Mechanical Engineering
# 1     Drosselmeyer, Dillon      Mechanical Eng - Aerospace
# 2           Angels, Nelson  EE-Antenn & Wirels Comm Spclty
# 3           Crane, Michael      Mechanical Eng - Aerospace
# 4          Elliott, Tanner          Mechanical Engineering
# ..                     ...                             ...
# 435     Sarff, Christopher  EE-Antenn & Wirels Comm Spclty
# 436            Noel, Reece          Mechanical Engineering
# 437           Araki, Shuta          Electrical Engineering
# 438  Gimadeyeva, Alexandra         Mechanical Eng - Energy
# 439         Hodges, Thomas       Environmental Engineering
#
#                                            desc  \
# id
# 0                                         Other
# 1    Professional project management experience
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 435                                  Leadership
# 436                                         NaN
# 437                                         NaN
# 438                                         NaN
# 439                                         NaN
#
#                                       secondary_skills  \
# id
# 0    ['Additive manufacturing', 'Circuit design', '...
# 1    ['Advance manufacturing courses, but not takin...
# 2                                                   []
# 3    ['Circuit design', 'Microcontroller interfacin...
# 4    ['Additive manufacturing', 'Advance manufactur...
# ..                                                 ...
# 435  ['Circuit design', 'Construction engineering',...
# 436  ['Circuit design', 'Construction engineering',...
# 437  ['Automotive experience', 'Construction engine...
# 438  ['Advance manufacturing courses, but not takin...
# 439  ['AutoCAD', 'Computer Science classes (e.g. CS...
#
#                                          project_order major
# id
# 0    [F23-11, F23-14, F23-50, F23-09, F23-64, F23-6...    ME
# 1    [F23-50, F23-51, F23-87, F23-88, F23-77, F23-7...    ME
# 2                                                   []    EE
# 3    [F23-63, F23-111, F23-75, F23-77, F23-73, F23-...    ME
# 4    [F23-60, F23-72, F23-51, F23-116, F23-101, F23...    ME
# ..                                                 ...   ...
# 435  [F23-64, F23-63, F23-89, F23-88, F23-17.1, F23...    EE
# 436  [F23-63, F23-64, F23-13, F23-61, F23-62, F23-6...    ME
# 437  [F23-111, F23-17.2, F23-17.1, F23-52, F23-20, ...    EE
# 438  [F23-101, F23-102, F23-17.2, F23-17.1, F23-63,...    ME
# 439  [F23-27, F23-22, F23-32, F23-31, F23-33, F23-2...  Env.
#
# [438 rows x 6 columns]

# %%
students = students_df[['major']].to_dict(orient='index')

# %%
project_preferences = students_df[['project_order']].to_dict(orient='dict')['project_order']

# %%
projects_df = pd.read_csv('projects.csv', index_col=0)
projects_df = projects_df.rename(columns={'ID': 'id', 'Project name': 'project_name', 'Sponsor': 'sponsor', 'majors_requested': 'majors'})
projects_df['majors'] = projects_df['majors'].apply(lambda x: json.loads(x))
projects_df = projects_df.set_index('id')
projects_df.head(3)
# Out:
#                        project_name sponsor  \
# id
# F23-01  AISC Steel Bridge - Team #1    AISC
# F23-02  AISC Steel Bridge - Team #2    AISC
# F23-03          ASCE Concrete Canoe    ASCE
#
#                                                    majors
# id
# F23-01  {'CE': 7, 'Env.': 0, 'EE': 0, 'ME': 0, 'DE': 0...
# F23-02  {'CE': 7, 'Env.': 0, 'EE': 0, 'ME': 0, 'DE': 0...
# F23-03  {'CE': 7, 'Env.': 0, 'EE': 0, 'ME': 0, 'DE': 0...

# %%
projects = projects_df.to_dict(orient='index')

# %% [markdown]
# ## Solve

# %%
solution = solve_student_project_assignment(students, projects, project_preferences)
solution = pd.DataFrame(solution)

# %%
student_merge = pd.merge(left=students_df, right=solution, left_index=True, right_on='student')
results = pd.merge(left=student_merge, right=projects_df, left_on='project', right_index=True).sort_values('student')

# %%
results[['student', 'name', 'degree', 'major', 'desc', 'secondary_skills', 'project_order', 'project', 'project_name', 'sponsor', 'majors']]
# Out:
#      student                   name                          degree major  \
# 0          0       Dechant, Bradley          Mechanical Engineering    ME
# 1          1   Drosselmeyer, Dillon      Mechanical Eng - Aerospace    ME
# 2          2         Angels, Nelson  EE-Antenn & Wirels Comm Spclty    EE
# 3          3         Crane, Michael      Mechanical Eng - Aerospace    ME
# 4          4        Elliott, Tanner          Mechanical Engineering    ME
# ..       ...                    ...                             ...   ...
# 433      435     Sarff, Christopher  EE-Antenn & Wirels Comm Spclty    EE
# 434      436            Noel, Reece          Mechanical Engineering    ME
# 435      437           Araki, Shuta          Electrical Engineering    EE
# 436      438  Gimadeyeva, Alexandra         Mechanical Eng - Energy    ME
# 437      439         Hodges, Thomas       Environmental Engineering  Env.
#
#                                            desc  \
# 0                                         Other
# 1    Professional project management experience
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 433                                  Leadership
# 434                                         NaN
# 435                                         NaN
# 436                                         NaN
# 437                                         NaN
#
#                                       secondary_skills  \
# 0    ['Additive manufacturing', 'Circuit design', '...
# 1    ['Advance manufacturing courses, but not takin...
# 2                                                   []
# 3    ['Circuit design', 'Microcontroller interfacin...
# 4    ['Additive manufacturing', 'Advance manufactur...
# ..                                                 ...
# 433  ['Circuit design', 'Construction engineering',...
# 434  ['Circuit design', 'Construction engineering',...
# 435  ['Automotive experience', 'Construction engine...
# 436  ['Advance manufacturing courses, but not takin...
# 437  ['AutoCAD', 'Computer Science classes (e.g. CS...
#
#                                          project_order   project  \
# 0    [F23-11, F23-14, F23-50, F23-09, F23-64, F23-6...    F23-11
# 1    [F23-50, F23-51, F23-87, F23-88, F23-77, F23-7...    F23-04
# 2                                                   []   F23-114
# 3    [F23-63, F23-111, F23-75, F23-77, F23-73, F23-...    F23-63
# 4    [F23-60, F23-72, F23-51, F23-116, F23-101, F23...    F23-60
# ..                                                 ...       ...
# 433  [F23-64, F23-63, F23-89, F23-88, F23-17.1, F23...    F23-64
# 434  [F23-63, F23-64, F23-13, F23-61, F23-62, F23-6...    F23-63
# 435  [F23-111, F23-17.2, F23-17.1, F23-52, F23-20, ...  F23-17.2
# 436  [F23-101, F23-102, F23-17.2, F23-17.1, F23-63,...   F23-101
# 437  [F23-27, F23-22, F23-32, F23-31, F23-33, F23-2...    F23-27
#
#                                           project_name  \
# 0        NASA Robotic Mining Competition - Lunabotics
# 1                       ASCE Timber Strong Competition
# 2                                 Little Pig in a Poke
# 3    Restoration 1930 Ford Model A Flatbed Steak Truck
# 4                         Multi-Axis Racecar Simulator
# ..                                                 ...
# 433   ICE Swap to Electric in Sunbeam Classic Car (II)
# 434  Restoration 1930 Ford Model A Flatbed Steak Truck
# 435  Jefferson County Campus Solar Resources Evalua...
# 436       Electroluminescence Camera Support Structure
# 437                  Creekside Park Hill Stabilization
#
#                                   sponsor  \
# 0            NASA & Mines Space Resources
# 1                                    ASCE
# 2    Craig Champlin - EE Doctoral Student
# 3                                   FRAPA
# 4                           ME Department
# ..                                    ...
# 433                          Thomas Eyers
# 434                                 FRAPA
# 435                      Jefferson County
# 436                 BrightSpot Automation
# 437                   City of Wheat Ridge
#
#                                                 majors
# 0    {'CE': 0, 'Env.': 0, 'EE': 1, 'ME': 8, 'DE': 0...
# 1    {'CE': 5, 'Env.': 0, 'EE': 0, 'ME': 8, 'DE': 0...
# 2    {'CE': 0, 'Env.': 0, 'EE': 3, 'ME': 3, 'DE': 0...
# 3    {'CE': 0, 'Env.': 0, 'EE': 1, 'ME': 7, 'DE': 0...
# 4    {'CE': 0, 'Env.': 0, 'EE': 4, 'ME': 6, 'DE': 0...
# ..                                                 ...
# 433  {'CE': 0, 'Env.': 2, 'EE': 3, 'ME': 3, 'DE': 0...
# 434  {'CE': 0, 'Env.': 0, 'EE': 1, 'ME': 7, 'DE': 0...
# 435  {'CE': 1, 'Env.': 0, 'EE': 2, 'ME': 2, 'DE': 0...
# 436  {'CE': 0, 'Env.': 0, 'EE': 2, 'ME': 3, 'DE': 0...
# 437  {'CE': 3, 'Env.': 2, 'EE': 0, 'ME': 0, 'DE': 0...
#
# [438 rows x 11 columns]

# %%
# results.to_csv('mips_solution.csv')

# %% [markdown]
# ## Analysis

# %%
def get_majors_by_project(lst):
    freq_dict = {}
    for el in lst:
        if el in freq_dict:
            freq_dict[el] += 1
        else:
            freq_dict[el] = 1
    res = list(freq_dict.items())
    res.sort(key=lambda x: x[1], reverse=True)
    return dict(res)

majors_by_project = results[['major', 'project', 'student']].groupby(['project']).agg({'major': ', '.join}).reset_index()
majors_by_project['major'] = majors_by_project['major'].apply(lambda x: x.split(', ')) # convert to list
majors_by_project['major'] = majors_by_project['major'].apply(lambda x: get_majors_by_project(x))
majors_by_project = majors_by_project.rename(columns={'major': 'majors_assigned'})
majors_by_project['students_assigned'] = majors_by_project['majors_assigned'].apply(lambda x: sum(x.values()))
majors_by_project = pd.merge(left=majors_by_project, right=projects_df, left_on='project', right_on='id')
majors_by_project['students_asked'] = majors_by_project['majors'].apply(lambda x: sum(x.values()))
majors_by_project = majors_by_project.sort_values('students_assigned')
majors_by_project
# Out:
#      project                  majors_assigned  students_assigned  \
# 3     F23-06                      {'Env.': 2}                  2
# 40    F23-42            {'EE': 2, 'Other': 1}                  3
# 27    F23-20               {'CE': 2, 'ME': 1}                  3
# 26  F23-17.5                        {'ME': 3}                  3
# 8    F23-100            {'ME': 3, 'Other': 1}                  4
# ..       ...                              ...                ...
# 2     F23-04               {'ME': 5, 'CE': 5}                 10
# 45    F23-60   {'ME': 6, 'EE': 4, 'Other': 1}                 11
# 19    F23-13              {'ME': 11, 'EE': 1}                 12
# 46    F23-61  {'ME': 12, 'EE': 4, 'Other': 1}                 17
# 21    F23-15              {'ME': 35, 'EE': 2}                 37
#
#                                          project_name  \
# 3                 South Platte Renew Process Upgrades
# 40                     Accessible Map of Mines Campus
# 27                 Public Restroom Use and Operations
# 26             Campus Food Pantry Design Optimization
# 8   Drying of mixed air/water stream in hydropower...
# ..                                                ...
# 2                      ASCE Timber Strong Competition
# 45                       Multi-Axis Racecar Simulator
# 19                                 Shell Eco-Marathon
# 46                   Quick Swap Modular EV Powertrain
# 21                                               HCDS
#
#                                               sponsor  \
# 3                                   RMWEA Competition
# 40  Jamie Regan - Student led (ODAC - Orediggers D...
# 27   City of Lakewood, Community Resources Department
# 26                    Estelle Cronmille - Student Led
# 8                           Flotation Pumping Company
# ..                                                ...
# 2                                                ASCE
# 45                                      ME Department
# 19                                              Shell
# 46                                      ME Department
# 21                                               HCDS
#
#                                                majors  students_asked
# 3   {'CE': 2, 'Env.': 2, 'EE': 0, 'ME': 0, 'DE': 2...               6
# 40  {'CE': 0, 'Env.': 0, 'EE': 3, 'ME': 0, 'DE': 0...               4
# 27  {'CE': 2, 'Env.': 1, 'EE': 1, 'ME': 1, 'DE': 0...               5
# 26  {'CE': 0, 'Env.': 0, 'EE': 0, 'ME': 3, 'DE': 1...               4
# 8   {'CE': 0, 'Env.': 1, 'EE': 0, 'ME': 3, 'DE': 2...               7
# ..                                                ...             ...
# 2   {'CE': 5, 'Env.': 0, 'EE': 0, 'ME': 8, 'DE': 0...              13
# 45  {'CE': 0, 'Env.': 0, 'EE': 4, 'ME': 6, 'DE': 0...              11
# 19  {'CE': 0, 'Env.': 0, 'EE': 1, 'ME': 11, 'DE': ...              12
# 46  {'CE': 0, 'Env.': 0, 'EE': 4, 'ME': 12, 'DE': ...              17
# 21  {'CE': 0, 'Env.': 0, 'EE': 2, 'ME': 35, 'DE': ...              37
#
# [69 rows x 7 columns]

# %%
for _, student in results.iterrows():
    if 'F23-06' in student['project_order']:
        print(student['name'], student['major'], student['project'], student['project_order'], student['majors'])
# Out:
# Misra, Anamika Env. F23-30 ['F23-30', 'F23-27', 'F23-21', 'F23-07', 'F23-06', 'F23-08', 'F23-33', 'F23-32'] {'CE': 3, 'Env.': 3, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Diaz, Brianna CE F23-23 ['F23-23', 'F23-21', 'F23-24', 'F23-17.3', 'F23-08', 'F23-06', 'F23-25', 'F23-22'] {'CE': 3, 'Env.': 2, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Donovan, Marcus Env. F23-08 ['F23-31', 'F23-32', 'F23-21', 'F23-08', 'F23-33', 'F23-07', 'F23-17.1', 'F23-06'] {'CE': 2, 'Env.': 2, 'EE': 0, 'ME': 2, 'DE': 0, 'Other': 0}
# Tepedelen, Dylan Env. F23-07 ['F23-07', 'F23-08', 'F23-06', 'F23-32', 'F23-31', 'F23-33', 'F23-100', 'F23-26'] {'CE': 2, 'Env.': 4, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Pennington, Brooke CE F23-32 ['F23-32', 'F23-31', 'F23-26', 'F23-27', 'F23-33', 'F23-24', 'F23-06', 'F23-21'] {'CE': 3, 'Env.': 3, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Lewis, Daniel Env. F23-31 ['F23-31', 'F23-26', 'F23-33', 'F23-06', 'F23-32', 'F23-08', 'F23-07', 'F23-30'] {'CE': 3, 'Env.': 3, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# O'Leary, Aidan Env. F23-31 ['F23-31', 'F23-33', 'F23-30', 'F23-08', 'F23-32', 'F23-06', 'F23-27', 'F23-21'] {'CE': 3, 'Env.': 3, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Coffey, Rachel Env. F23-08 ['F23-08', 'F23-07', 'F23-33', 'F23-32', 'F23-31', 'F23-06', 'F23-30', 'F23-23'] {'CE': 2, 'Env.': 2, 'EE': 0, 'ME': 2, 'DE': 0, 'Other': 0}
# Pellegrino, Isabella Env. F23-06 ['F23-33', 'F23-06', 'F23-08', 'F23-31', 'F23-32', 'F23-07', 'F23-30', 'F23-21'] {'CE': 2, 'Env.': 2, 'EE': 0, 'ME': 0, 'DE': 2, 'Other': 0}
# Hanson, Graycen Env. F23-31 ['F23-31', 'F23-32', 'F23-33', 'F23-08', 'F23-06', 'F23-21', 'F23-27', 'F23-30'] {'CE': 3, 'Env.': 3, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Stenhouse, Cameron ME F23-80 ['F23-80', 'F23-01', 'F23-03', 'F23-04', 'F23-06', 'F23-07'] {'CE': 0, 'Env.': 0, 'EE': 2, 'ME': 5, 'DE': 1, 'Other': 0}
# Haskell, Emma Env. F23-33 ['F23-33', 'F23-30', 'F23-32', 'F23-31', 'F23-17.2', 'F23-17.3', 'F23-22', 'F23-06'] {'CE': 4, 'Env.': 2, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Parsons, Khloe Env. F23-23 ['F23-24', 'F23-33', 'F23-31', 'F23-32', 'F23-23', 'F23-06', 'F23-64', 'F23-27'] {'CE': 3, 'Env.': 2, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Winkelmann, Andrew CE F23-26 ['F23-26', 'F23-01', 'F23-04', 'F23-23', 'F23-06', 'F23-03', 'F23-17.2', 'F23-24'] {'CE': 4, 'Env.': 0, 'EE': 0, 'ME': 0, 'DE': 2, 'Other': 0}
# Leszczak, Emma Env. F23-06 ['F23-06', 'F23-08', 'F23-07', 'F23-17.4', 'F23-33', 'F23-17.3', 'F23-32', 'F23-21'] {'CE': 2, 'Env.': 2, 'EE': 0, 'ME': 0, 'DE': 2, 'Other': 0}
# Barta, Emma Env. F23-32 ['F23-32', 'F23-33', 'F23-06', 'F23-31', 'F23-22', 'F23-08', 'F23-100', 'F23-30'] {'CE': 3, 'Env.': 3, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
# Fristed, Hannah Env. F23-22 ['F23-33', 'F23-32', 'F23-31', 'F23-30', 'F23-22', 'F23-21', 'F23-17.4', 'F23-06'] {'CE': 2, 'Env.': 2, 'EE': 0, 'ME': 0, 'DE': 0, 'Other': 0}
